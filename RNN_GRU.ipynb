# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# csvファイルからPandas DataFrameへ読み込み
train = pd.read_csv('train.csv', delimiter=',', low_memory=False)
test = pd.read_csv('test.csv', delimiter=',', low_memory=False)

# 冒頭を表示して確認
train.head()
# Out:
#              date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0  2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1  2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2  2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3  2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4  2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides
# 0            12.0                   167.7
# 1             9.9                    98.9
# 2             9.2                   127.1
# 3             9.7                   177.2
# 4             6.4                   121.8

# %%
# trainデータを入力データとラベルに分割する
X = train.drop(['date_time'], axis=1).drop(['target_carbon_monoxide'], axis=1).drop(['target_benzene'], axis=1).drop(['target_nitrogen_oxides'], axis=1).values
Y_1 = train.target_carbon_monoxide.values  # carbon_monoxide(一酸化炭素)
Y_2 = train.target_benzene.values          # benzene(ベンゼン)
Y_3 = train.target_nitrogen_oxides.values  # nitrogen_oxides(窒素酸化物)

# 表示して確認
X, Y_1
# Out:
# (array([[1.3100e+01, 4.6000e+01, 7.5780e-01, ..., 1.0560e+03, 1.7428e+03,
#          1.2934e+03],
#         [1.3200e+01, 4.5300e+01, 7.2550e-01, ..., 1.1975e+03, 1.4499e+03,
#          1.0109e+03],
#         [1.2600e+01, 5.6200e+01, 7.5020e-01, ..., 1.0602e+03, 1.5861e+03,
#          1.1170e+03],
#         ...,
#         [9.6000e+00, 3.4600e+01, 4.3100e-01, ..., 8.6190e+02, 8.8920e+02,
#          1.1591e+03],
#         [8.0000e+00, 4.0700e+01, 4.0850e-01, ..., 9.0850e+02, 9.1700e+02,
#          1.2063e+03],
#         [8.0000e+00, 4.1300e+01, 4.3750e-01, ..., 7.9710e+02, 8.8000e+02,
#          1.2731e+03]]),
#  array([2.5, 2.1, 2.2, ..., 1.6, 1.5, 1.4]))

# %%
# データを訓練データと検証データに分割する
def split_data(X, Y):
    # trainデータを訓練データと検証データに分割する
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    return x_train, x_test, y_train, y_test

# %%
# RMSLE カスタム評価関数 #####################
from keras import backend as K
msle = keras.metrics.MeanSquaredLogarithmicError()

def root_mean_squared_logarithmic_error(y_true, y_pred):
    return K.sqrt(msle(y_true, y_pred))

# %%
# RNN(LSTM)モデルをセット
def model_set():
    # RNN(LSTM)モデルを構築
    model = keras.Sequential([
            keras.layers.GRU(1, batch_input_shape=(None, 8, 1), return_sequences=True),
    ])
    
    # モデルをコンパイルして構造を表示
    model.compile(optimizer='adam', #rmsprop
                  loss='mean_squared_error')
    model.summary()
    
    return model

# %% [markdown]
# # carbon_monoxide(一酸化炭素)について------------------------

# %%
# データを訓練データと検証データに分割する
x_train, x_test, y_train, y_test = split_data(X, Y_1)

# 形を表示して確認
((x_train.shape, x_test.shape), (y_train.shape, y_test.shape))
# Out:
# (((5688, 8), (1423, 8)), ((5688,), (1423,)))

# %%
# RNN(LSTM)モデルをセット
model_1 = model_set()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 8, 1)              12
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 学習させる
model_1.fit(x_train.reshape(-1, 8, 1), y_train, batch_size=256, epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 9ms/step - loss: 6.5879
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 6.5186
# Epoch 3/100
# 23/23 [==============================] - 0s 3ms/step - loss: 6.3965
# Epoch 4/100
# 23/23 [==============================] - 0s 3ms/step - loss: 6.3528
# Epoch 5/100
# 23/23 [==============================] - 0s 3ms/step - loss: 6.2712
# Epoch 6/100
# 23/23 [==============================] - 0s 3ms/step - loss: 6.1074
# Epoch 7/100
# 23/23 [==============================] - 0s 3ms/step - loss: 5.9707
# Epoch 8/100
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8766
# Epoch 9/100
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7489
# Epoch 10/100
# 23/23 [==============================] - 0s 3ms/step - loss: 5.6403
# Epoch 11/100
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1011
# Epoch 12/100
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4922
# Epoch 13/100
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3667
# Epoch 14/100
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3568
# Epoch 15/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.4388
# Epoch 16/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.2389
# Epoch 17/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.4112
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.3624
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.3182
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.2215
# Epoch 21/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.3037
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.4334
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.4477
# Epoch 24/100
# 23/23 [==============================] - 0s 5ms/step - loss: 3.2777
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.3273
# Epoch 26/100
# 23/23 [==============================] - 0s 11ms/step - loss: 3.1434
# Epoch 27/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.2516
# Epoch 28/100
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2187
# Epoch 29/100
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2312
# Epoch 30/100
# 23/23 [==============================] - 0s 3ms/step - loss: 3.1679
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 3.
# Epoch 81/100
# 23/23 [==============================] - 0s 4ms/step - loss: 145.4265
# Epoch 82/100
# 23/23 [==============================] - 0s 4ms/step - loss: 145.4626
# Epoch 83/100
# 23/23 [==============================] - 0s 4ms/step - loss: 146.2650
# Epoch 84/100
# 23/23 [==============================] - 0s 4ms/step - loss: 144.9626
# Epoch 85/100
# 23/23 [==============================] - 0s 4ms/step - loss: 140.9876
# Epoch 86/100
# 23/23 [==============================] - 0s 4ms/step - loss: 146.2399
# Epoch 87/100
# 23/23 [==============================] - 0s 4ms/step - loss: 147.7898
# Epoch 88/100
# 23/23 [==============================] - 0s 4ms/step - loss: 142.1129
# Epoch 89/100
# 23/23 [==============================] - 0s 4ms/step - loss: 147.6140
# Epoch 90/100
# 23/23 [==============================] - 0s 4ms/step - loss: 148.5244
# Epoch 91/100
# 23/23 [==============================] - 0s 4ms/step - loss: 142.4210
# Epoch 92/100
# 23/23 [==============================] - 0s 4ms/step - loss: 145.7806
# Epoch 93/100
# 23/23 [==============================] - 0s 4ms/step - loss: 149.6925
# Epoch 94/100
# 23/23 [==============================] - 0s 4ms/step - loss: 149.5742
# Epoch 95/100
# 23/23 [==============================] - 0s 7ms/step - loss: 142.4557
# Epoch 96/100
# 23/23 [==============================] - 0s 9ms/step - loss: 145.5840
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 147.2640
# Epoch 98/100
# 23/23 [==============================] - 0s 4ms/step - loss: 142.3259
# Epoch 99/100
# 23/23 [==============================] - 0s 4ms/step - loss: 142.2741
# Epoch 100/100
# 23/23 [==============================] - 0s 3ms/step - loss: 141.2658

# %%
# 検証データへの精度
y_test_pred = model_2.predict(x_test.reshape(-1, 8, 1))[:,0]
print('RMSLE: %.3f' % root_mean_squared_logarithmic_error(y_test, y_test_pred))
print('r2: %.3f' % r2_score(y_test, y_test_pred))
# Out:
# RMSLE: 1.243
# r2: -1.440

# %% [markdown]
# # nitrogen_oxides(窒素酸化物)について-------------------------

# %%
# データを訓練データと検証データに分割する
x_train, x_test, y_train, y_test = split_data(X, Y_3)

# 形を表示して確認
((x_train.shape, x_test.shape), (y_train.shape, y_test.shape))
# Out:
# (((5688, 8), (1423, 8)), ((5688,), (1423,)))

# %%
# RNN(LSTM)モデルをセット
model_3 = model_set()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_2 (GRU)                  (None, 8, 1)              12
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 学習させる
model_3.fit(x_train.reshape(-1, 8, 1), y_train, batch_size=256, epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 1s 5ms/step - loss: 73693.1533
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78199.0202
# Epoch 3/100
# 23/23 [==============================] - 0s 4ms/step - loss: 81028.2064
# Epoch 4/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75399.4671
# Epoch 5/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78241.1315
# Epoch 6/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76526.4930
# Epoch 7/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78155.2380
# Epoch 8/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80845.9873
# Epoch 9/100
# 23/23 [==============================] - 0s 5ms/step - loss: 80358.7422
# Epoch 10/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77731.7077
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 83890.7100
# Epoch 12/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79862.5599
# Epoch 13/100
# 23/23 [==============================] - 0s 5ms/step - loss: 81366.0456
# Epoch 14/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77631.8942
# Epoch 15/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77810.8883
# Epoch 16/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79296.6501
# Epoch 17/100
# 23/23 [==============================] - 0s 5ms/step - loss: 75469.0368
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76797.5882
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80260.2448
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77655.4339
# Epoch 21/100
# 23/23 [==============================] - 0s 4ms/step - loss: 74960.7804
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76297.5822
# Epoch 23/100
# 23/23 [==============================] - 0s 5ms/step - loss: 76733.6966
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75917.2941
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77599.1657
# Epoch 26/100
# 23/23 [==============================] - 0s 4ms/step - loss: 81332.8633
# Epoch 27/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79261.4180
# Epoch 28/100
# 23/23 [==============================] - 0s 5ms/step - loss: 80239.6523
# Epoch 29/100
# 23/23 [==============================] - 0s 5ms/step - loss: 77603.3395
# Epoch 30/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79949.4997
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79955.5993
# Epoch 32/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77465.8646
# Epoch 33/100
# 23/23 [==============================] - 0s 4ms/step - loss: 74304.0885
# Epoch 34/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78206.7894
# Epoch 35/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78249.6676
# Epoch 36/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78708.6087
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 83466.5684
# Epoch 38/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78893.6191
# Epoch 39/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78835.3584
# Epoch 40/100
# 23/23 [==============================] - 0s 4ms/step - loss: 74929.9362
# Epoch 41/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75773.7201
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75481.9899
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76923.6045
# Epoch 44/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79389.0221
# Epoch 45/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76566.9805
# Epoch 46/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76307.9352
# Epoch 47/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77844.7568
# Epoch 48/100
# 23/23 [==============================] - 0s 8ms/step - loss: 79451.8822
# Epoch 49/100
# 23/23 [==============================] - 0s 7ms/step - loss: 77274.1217
# Epoch 50/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79139.2409
# Epoch 51/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79284.1803
# Epoch 52/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77715.8438
# Epoch 53/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78133.5856
# Epoch 54/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80736.2552
# Epoch 55/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79883.3447
# Epoch 56/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80143.7852
# Epoch 57/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77793.1107
# Epoch 58/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76551.4941
# Epoch 59/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77568.7943
# Epoch 60/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75396.5887
# Epoch 61/100
# 23/23 [==============================] - 0s 5ms/step - loss: 82172.5703
# Epoch 62/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77782.8939
# Epoch 63/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77562.6335
# Epoch 64/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80164.0804
# Epoch 65/100
# 23/23 [==============================] - 0s 5ms/step - loss: 76283.0918
# Epoch 66/100
# 23/23 [==============================] - 0s 11ms/step - loss: 78423.0221
# Epoch 67/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77717.8525
# Epoch 68/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80178.3314
# Epoch 69/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75475.4479
# Epoch 70/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80876.3633
# Epoch 71/100
# 23/23 [==============================] - 0s 4ms/step - loss: 74188.4787
# Epoch 72/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79959.7116
# Epoch 73/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77139.0612
# Epoch 74/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80408.3590
# Epoch 75/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76689.8210
# Epoch 76/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78382.8564
# Epoch 77/100
# 23/23 [==============================] - 0s 4ms/step - loss: 73875.2829
# Epoch 78/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80019.3503
# Epoch 79/100
# 23/23 [==============================] - 0s 4ms/step - loss: 80219.9544
# Epoch 80/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76776.5101
# Epoch 81/100
# 23/23 [==============================] - 0s 7ms/step - loss: 77597.6566
# Epoch 82/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75535.3320
# Epoch 83/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76781.0254
# Epoch 84/100
# 23/23 [==============================] - 0s 4ms/step - loss: 81978.9476
# Epoch 85/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78677.5609
# Epoch 86/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77605.1667
# Epoch 87/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76186.1768
# Epoch 88/100
# 23/23 [==============================] - 0s 6ms/step - loss: 79735.9808
# Epoch 89/100
# 23/23 [==============================] - 0s 8ms/step - loss: 81210.9066
# Epoch 90/100
# 23/23 [==============================] - 0s 4ms/step - loss: 77387.9072
# Epoch 91/100
# 23/23 [==============================] - 0s 6ms/step - loss: 81239.4967
# Epoch 92/100
# 23/23 [==============================] - 0s 4ms/step - loss: 76286.1683
# Epoch 93/100
# 23/23 [==============================] - 0s 5ms/step - loss: 80914.3509
# Epoch 94/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79065.4723
# Epoch 95/100
# 23/23 [==============================] - 0s 4ms/step - loss: 78323.8796
# Epoch 96/100
# 23/23 [==============================] - 0s 4ms/step - loss: 81156.2930
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 75903.7646
# Epoch 98/100
# 23/23 [==============================] - 0s 4ms/step - loss: 79301.8112
# Epoch 99/100
# 23/23 [==============================] - 0s 5ms/step - loss: 78404.1504
# Epoch 100/100
# 23/23 [==============================] - 0s 7ms/step - loss: 76862.4336A: 0s - loss: 72248.5

# %%
# 検証データへの精度
y_test_pred = model_3.predict(x_test.reshape(-1, 8, 1))[:,0]
print('RMSLE: %.3f' % root_mean_squared_logarithmic_error(y_test, y_test_pred))
print('r2: %.3f' % r2_score(y_test, y_test_pred))
# Out:
# RMSLE: 2.733
# r2: -1.158

# %% [markdown]
# # 提出データへの適用

# %%
# testデータを適用できる形に変換する
X_sb = test.drop(['date_time'], axis=1).values

# 表示して確認
X_sb
# Out:
# array([[8.0000e+00, 4.1300e+01, 4.3750e-01, ..., 7.9710e+02, 8.8000e+02,
#         1.2731e+03],
#        [5.1000e+00, 5.1700e+01, 4.5640e-01, ..., 6.8790e+02, 9.7280e+02,
#         1.7140e+03],
#        [5.8000e+00, 5.1500e+01, 4.6890e-01, ..., 6.9370e+02, 9.4190e+02,
#         1.3008e+03],
#        ...,
#        [2.6600e+01, 1.9000e+01, 6.4060e-01, ..., 5.7280e+02, 1.2534e+03,
#         1.0811e+03],
#        [2.9100e+01, 1.2700e+01, 5.1390e-01, ..., 7.0200e+02, 1.0098e+03,
#         8.0850e+02],
#        [2.7900e+01, 1.3500e+01, 5.0280e-01, ..., 6.0820e+02, 1.0613e+03,
#         8.1600e+02]])

# %%
# 各目的変数を回帰
predict_1 = pd.DataFrame(model_1.predict(X_sb.reshape(-1, 8, 1))[:,0])
predict_2 = pd.DataFrame(model_2.predict(X_sb.reshape(-1, 8, 1))[:,0])
predict_3 = pd.DataFrame(model_3.predict(X_sb.reshape(-1, 8, 1))[:,0])

# データの形を確認
predict_1.shape, predict_2.shape, predict_3.shape
# Out:
# ((2247, 1), (2247, 1), (2247, 1))

# %%
# 結果を提出形式に変形
df_predictions = pd.concat([predict_1, predict_2, predict_3],axis=1)
df_predictions.columns = ['target_carbon_monoxide', 'target_benzene', 'target_nitrogen_oxides']
submit_data = pd.concat([test.date_time, df_predictions],axis=1)
submit_data = submit_data.set_index('date_time')
submit_data.head()
# Out:
#                      target_carbon_monoxide  target_benzene  \
# date_time
# 2011-01-01 00:00:00                0.909209        0.972321
# 2011-01-01 01:00:00                0.834409        0.939072
# 2011-01-01 02:00:00                0.857543        0.952514
# 2011-01-01 03:00:00                0.830752        0.936648
# 2011-01-01 04:00:00                0.810952        0.922057
#
#                      target_nitrogen_oxides
# date_time
# 2011-01-01 00:00:00                0.949410
# 2011-01-01 01:00:00                0.906449
# 2011-01-01 02:00:00                0.919133
# 2011-01-01 03:00:00                0.904497
# 2011-01-01 04:00:00                0.894176

# %%
# CSVファイルとして出力
submit_data.to_csv("submission_RNN_GRU.csv")
