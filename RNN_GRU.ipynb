# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# csvファイルからPandas DataFrameへ読み込み
train = pd.read_csv('train.csv', delimiter=',', low_memory=False)
test = pd.read_csv('test.csv', delimiter=',', low_memory=False)

# 冒頭を表示して確認
train.head()
# Out:
#              date_time  deg_C  relative_humidity  absolute_humidity  sensor_1  \
# 0  2010-03-10 18:00:00   13.1               46.0             0.7578    1387.2
# 1  2010-03-10 19:00:00   13.2               45.3             0.7255    1279.1
# 2  2010-03-10 20:00:00   12.6               56.2             0.7502    1331.9
# 3  2010-03-10 21:00:00   11.0               62.4             0.7867    1321.0
# 4  2010-03-10 22:00:00   11.9               59.0             0.7888    1272.0
#
#    sensor_2  sensor_3  sensor_4  sensor_5  target_carbon_monoxide  \
# 0    1087.8    1056.0    1742.8    1293.4                     2.5
# 1     888.2    1197.5    1449.9    1010.9                     2.1
# 2     929.6    1060.2    1586.1    1117.0                     2.2
# 3     929.0    1102.9    1536.5    1263.2                     2.2
# 4     852.7    1180.9    1415.5    1132.2                     1.5
#
#    target_benzene  target_nitrogen_oxides
# 0            12.0                   167.7
# 1             9.9                    98.9
# 2             9.2                   127.1
# 3             9.7                   177.2
# 4             6.4                   121.8

# %%
# trainデータを入力データとラベルに分割する
X = train.drop(['date_time'], axis=1).drop(['target_carbon_monoxide'], axis=1).drop(['target_benzene'], axis=1).drop(['target_nitrogen_oxides'], axis=1).values
Y_1 = train.target_carbon_monoxide.values  # carbon_monoxide(一酸化炭素)
Y_2 = train.target_benzene.values          # benzene(ベンゼン)
Y_3 = train.target_nitrogen_oxides.values  # nitrogen_oxides(窒素酸化物)

# 表示して確認
X, Y_1
# Out:
# (array([[1.3100e+01, 4.6000e+01, 7.5780e-01, ..., 1.0560e+03, 1.7428e+03,
#          1.2934e+03],
#         [1.3200e+01, 4.5300e+01, 7.2550e-01, ..., 1.1975e+03, 1.4499e+03,
#          1.0109e+03],
#         [1.2600e+01, 5.6200e+01, 7.5020e-01, ..., 1.0602e+03, 1.5861e+03,
#          1.1170e+03],
#         ...,
#         [9.6000e+00, 3.4600e+01, 4.3100e-01, ..., 8.6190e+02, 8.8920e+02,
#          1.1591e+03],
#         [8.0000e+00, 4.0700e+01, 4.0850e-01, ..., 9.0850e+02, 9.1700e+02,
#          1.2063e+03],
#         [8.0000e+00, 4.1300e+01, 4.3750e-01, ..., 7.9710e+02, 8.8000e+02,
#          1.2731e+03]]),
#  array([2.5, 2.1, 2.2, ..., 1.6, 1.5, 1.4]))

# %%
# データを訓練データと検証データに分割する
def split_data(X, Y):
    # trainデータを訓練データと検証データに分割する
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    
    return x_train, x_test, y_train, y_test

# %%
# RMSLE カスタム評価関数 #####################
from keras import backend as K
msle = keras.metrics.MeanSquaredLogarithmicError()

def root_mean_squared_logarithmic_error(y_true, y_pred):
    return K.sqrt(msle(y_true, y_pred))

# %%
# RNN(LSTM)モデルをセット
def model_set():
    # RNN(LSTM)モデルを構築
    model = keras.Sequential([
            keras.layers.GRU(10, batch_input_shape=(None, 8, 1), return_sequences=True),
            keras.layers.Dense(10, activation='relu'),
            keras.layers.Dense(1)
    ])
    
    # モデルをコンパイルして構造を表示
    model.compile(optimizer='adam', #rmsprop
                  loss='mean_squared_error')
    model.summary()
    
    return model

# %% [markdown]
# # carbon_monoxide(一酸化炭素)について------------------------

# %%
# データを訓練データと検証データに分割する
x_train, x_test, y_train, y_test = split_data(X, Y_1)

# 形を表示して確認
((x_train.shape, x_test.shape), (y_train.shape, y_test.shape))
# Out:
# (((5688, 8), (1423, 8)), ((5688,), (1423,)))

# %%
# RNN(LSTM)モデルをセット
model_1 = model_set()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 8, 10)             390
# _________________________________________________________________
# dense (Dense)                (None, 8, 10)             110
# _________________________________________________________________
# dense_1 (Dense)              (None, 8, 1)              11
# =================================================================
# Total params: 511
# Trainable params: 511
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 学習させる
model_1.fit(x_train.reshape(-1, 8, 1), y_train, batch_size=256, epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 3s 6ms/step - loss: 13.6894
# Epoch 2/100
# 23/23 [==============================] - 0s 7ms/step - loss: 10.5299
# Epoch 3/100
# 23/23 [==============================] - 0s 7ms/step - loss: 6.4188
# Epoch 4/100
# 23/23 [==============================] - 0s 7ms/step - loss: 4.2205
# Epoch 5/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.9943
# Epoch 6/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.3633
# Epoch 7/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.3477
# Epoch 8/100
# 23/23 [==============================] - 0s 10ms/step - loss: 2.2625
# Epoch 9/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.2232
# Epoch 10/100
# 23/23 [==============================] - 0s 10ms/step - loss: 2.1875
# Epoch 11/100
# 23/23 [==============================] - 0s 10ms/step - loss: 2.0650
# Epoch 12/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.1795
# Epoch 13/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.1163
# Epoch 14/100
# 23/23 [==============================] - 0s 8ms/step - loss: 2.1741
# Epoch 15/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.1753
# Epoch 16/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.0833
# Epoch 17/100
# 23/23 [==============================] - 0s 10ms/step - loss: 2.1969
# Epoch 18/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0772
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.1689
# Epoch 20/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0513
# Epoch 21/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.1390
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.1462
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.1593
# Epoch 24/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0867
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0900
# Epoch 26/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.0467
# Epoch 27/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.1506
# Epoch 28/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0768
# Epoch 29/100
# 23/23 [==============================] - ETA: 0s - loss: 2.083 - 0s 7ms/step - loss: 2.0847
# Epoch 30/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0265
# Epoch 31/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0808
# Epoch 32/100
# 23/23 [==============================] - 0s 19ms/step - loss: 2.1554
# Epoch 33/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0992
# Epoch 34/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0999
# Epoch 35/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.1276
# Epoch 36/100
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0936
# Epoch 37/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0778
# Epoch 38/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0864
# Epoch 39/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.1333
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.1182
# Epoch 41/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.1153
# Epoch 42/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.1376
# Epoch 43/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0356
# Epoch 44/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0554
# Epoch 45/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0706
# Epoch 46/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.1254
# Epoch 47/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.1805
# Epoch 48/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.0945
# Epoch 49/100
# 23/23 [==============================] - 0s 5ms/step - loss: 2.1111
# Epoch 50/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0658
# Epoch 51/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0993
# Epoch 52/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0083
# Epoch 53/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0318
# Epoch 54/100
# 23/23 [==============================] - 0s 9ms/step - loss: 2.0350
# Epoch 55/100
# 23/23 [==============================] - 0s 8ms/step - loss: 2.0319
# Epoch 56/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.0384
# Epoch 57/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.0246
# Epoch 58/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0240
# Epoch 59/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.9346
# Epoch 60/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.9711
# Epoch 61/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0626
# Epoch 62/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0224
# Epoch 63/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.0263
# Epoch 64/100
# 23/23 [==============================] - 0s 9ms/step - loss: 1.9745
# Epoch 65/100
# 23/23 [==============================] - 0s 8ms/step - loss: 1.9853
# Epoch 66/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0784
# Epoch 67/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0428
# Epoch 68/100
# 23/23 [==============================] - 0s 6ms/step - loss: 2.0080
# Epoch 69/100
# 23/23 [==============================] - 0s 7ms/step - loss: 2.0315
# Epoch 70/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.9543
# Epoch 71/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.9325
# Epoch 72/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.8890
# Epoch 73/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.8504
# Epoch 74/100
# 23/23 [==============================] - 0s 8ms/step - loss: 1.8936
# Epoch 75/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.9346
# Epoch 76/100
# 23/23 [==============================] - 0s 8ms/step - loss: 1.9186
# Epoch 77/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.7903
# Epoch 78/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.8135
# Epoch 79/100
# 23/23 [==============================] - 0s 12ms/step - loss: 1.8936
# Epoch 80/100
# 23/23 [==============================] - 0s 8ms/step - loss: 1.8572
# Epoch 81/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.7022
# Epoch 82/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.8185
# Epoch 83/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.8162
# Epoch 84/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.8068
# Epoch 85/100
# 23/23 [==============================] - 0s 8ms/step - loss: 1.8459
# Epoch 86/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.7741
# Epoch 87/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7802
# Epoch 88/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7854
# Epoch 89/100
# 23/23 [==============================] - 0s 13ms/step - loss: 1.7167
# Epoch 90/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7311
# Epoch 91/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7860
# Epoch 92/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7742
# Epoch 93/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7357
# Epoch 94/100
# 23/23 [==============================] - 0s 9ms/step - loss: 1.7941
# Epoch 95/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.6934
# Epoch 96/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7398
# Epoch 97/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.6393
# Epoch 98/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.6388
# Epoch 99/100
# 23/23 [==============================] - 0s 6ms/step - loss: 1.7328
# Epoch 100/100
# 23/23 [==============================] - 0s 7ms/step - loss: 1.6619

# %%
# 検証データへの精度
y_test_pred = model_1.predict(x_test.reshape(-1, 8, 1))[:,0]
print('RMSLE: %.3f' % root_mean_squared_logarithmic_error(y_test, y_test_pred))
print('r2: %.3f' % r2_score(y_test, y_test_pred))
# Out:
# RMSLE: 0.435
# r2: -0.002

# %% [markdown]
# # benzene(ベンゼン)について---------------------------------

# %%
# データを訓練データと検証データに分割する
x_train, x_test, y_train, y_test = split_data(X, Y_2)

# 形を表示して確認
((x_train.shape, x_test.shape), (y_train.shape, y_test.shape))
# Out:
# (((5688, 8), (1423, 8)), ((5688,), (1423,)))

# %%
# RNN(LSTM)モデルをセット
model_2 = model_set()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 8, 10)             390
# _________________________________________________________________
# dense_2 (Dense)              (None, 8, 10)             110
# _________________________________________________________________
# dense_3 (Dense)              (None, 8, 1)              11
# =================================================================
# Total params: 511
# Trainable params: 511
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 学習させる
model_2.fit(x_train.reshape(-1, 8, 1), y_train, batch_size=256, epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 3s 6ms/step - loss: 128.0306
# Epoch 2/100
# 23/23 [==============================] - 0s 6ms/step - loss: 118.5938
# Epoch 3/100
# 23/23 [==============================] - 0s 6ms/step - loss: 105.2550
# Epoch 4/100
# 23/23 [==============================] - 0s 6ms/step - loss: 92.9903
# Epoch 5/100
# 23/23 [==============================] - 0s 6ms/step - loss: 85.6465
# Epoch 6/100
# 23/23 [==============================] - 0s 5ms/step - loss: 80.2667
# Epoch 7/100
# 23/23 [==============================] - 0s 6ms/step - loss: 69.6586
# Epoch 8/100
# 23/23 [==============================] - 0s 6ms/step - loss: 66.0667
# Epoch 9/100
# 23/23 [==============================] - 0s 4ms/step - loss: 61.7017
# Epoch 10/100
# 23/23 [==============================] - 0s 4ms/step - loss: 60.8016
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 58.1531
# Epoch 12/100
# 23/23 [==============================] - 0s 4ms/step - loss: 59.7789
# Epoch 13/100
# 23/23 [==============================] - 0s 4ms/step - loss: 60.1542
# Epoch 14/100
# 23/23 [==============================] - 0s 5ms/step - loss: 57.9695
# Epoch 15/100
# 23/23 [==============================] - 0s 5ms/step - loss: 54.9059
# Epoch 16/100
# 23/23 [==============================] - 0s 5ms/step - loss: 59.4152
# Epoch 17/100
# 23/23 [==============================] - 0s 5ms/step - loss: 55.7976
# Epoch 18/100
# 23/23 [==============================] - 0s 5ms/step - loss: 57.4792
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 59.0479
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 60.0434
# Epoch 21/100
# 23/23 [==============================] - 0s 4ms/step - loss: 59.8062
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.3953
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 58.4054
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 58.0519
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 59.7068
# Epoch 26/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.5011
# Epoch 27/100
# 23/23 [==============================] - 0s 4ms/step - loss: 60.6622
# Epoch 28/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.0581
# Epoch 29/100
# 23/23 [==============================] - 0s 4ms/step - loss: 56.7390
# Epoch 30/100
# 23/23 [==============================] - 0s 4ms/step - loss: 58.6144
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 59.8185
# Epoch 32/100
# 23/23 [==============================] - 0s 5ms/step - loss: 58.5566
# Epoch 33/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.8704
# Epoch 34/100
# 23/23 [==============================] - 0s 4ms/step - loss: 58.9383
# Epoch 35/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.0610
# Epoch 36/100
# 23/23 [==============================] - 0s 4ms/step - loss: 56.7631
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 58.8446
# Epoch 38/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.2554
# Epoch 39/100
# 23/23 [==============================] - 0s 4ms/step - loss: 56.1851
# Epoch 40/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.2281
# Epoch 41/100
# 23/23 [==============================] - 0s 4ms/step - loss: 54.0217
# Epoch 42/100
# 23/23 [==============================] - 0s 4ms/step - loss: 57.6720
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 54.7019
# Epoch 44/100
# 23/23 [==============================] - 0s 4ms/step - loss:
# Epoch 73/100
# 23/23 [==============================] - 0s 4ms/step - loss: 39151.7305
# Epoch 74/100
# 23/23 [==============================] - 0s 5ms/step - loss: 36900.6613
# Epoch 75/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37931.7743
# Epoch 76/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37300.6685
# Epoch 77/100
# 23/23 [==============================] - 0s 6ms/step - loss: 39013.9295
# Epoch 78/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37785.6216
# Epoch 79/100
# 23/23 [==============================] - 0s 5ms/step - loss: 38291.1354
# Epoch 80/100
# 23/23 [==============================] - 0s 4ms/step - loss: 39355.9321
# Epoch 81/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37905.1182
# Epoch 82/100
# 23/23 [==============================] - 0s 4ms/step - loss: 37126.1605
# Epoch 83/100
# 23/23 [==============================] - 0s 4ms/step - loss: 37025.8672
# Epoch 84/100
# 23/23 [==============================] - 0s 4ms/step - loss: 38320.1704
# Epoch 85/100
# 23/23 [==============================] - 0s 4ms/step - loss: 36360.1143
# Epoch 86/100
# 23/23 [==============================] - 0s 5ms/step - loss: 36139.1104
# Epoch 87/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37883.8560
# Epoch 88/100
# 23/23 [==============================] - 0s 5ms/step - loss: 38477.1824
# Epoch 89/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37124.3586
# Epoch 90/100
# 23/23 [==============================] - 0s 4ms/step - loss: 37816.5459
# Epoch 91/100
# 23/23 [==============================] - 0s 6ms/step - loss: 35752.2476
# Epoch 92/100
# 23/23 [==============================] - 0s 9ms/step - loss: 35947.8550
# Epoch 93/100
# 23/23 [==============================] - 0s 5ms/step - loss: 38250.2573
# Epoch 94/100
# 23/23 [==============================] - 0s 4ms/step - loss: 38813.5754
# Epoch 95/100
# 23/23 [==============================] - 0s 4ms/step - loss: 38007.0765
# Epoch 96/100
# 23/23 [==============================] - 0s 5ms/step - loss: 37536.6410
# Epoch 97/100
# 23/23 [==============================] - 0s 6ms/step - loss: 39728.5521
# Epoch 98/100
# 23/23 [==============================] - 0s 4ms/step - loss: 37425.9598
# Epoch 99/100
# 23/23 [==============================] - 0s 4ms/step - loss: 37389.0739
# Epoch 100/100
# 23/23 [==============================] - 0s 4ms/step - loss: 37149.9876

# %%
# 検証データへの精度
y_test_pred = model_3.predict(x_test.reshape(-1, 8, 1))[:,0]
print('RMSLE: %.3f' % root_mean_squared_logarithmic_error(y_test, y_test_pred))
print('r2: %.3f' % r2_score(y_test, y_test_pred))
# Out:
# RMSLE: 0.746
# r2: -0.001

# %% [markdown]
# # 提出データへの適用

# %%
# testデータを適用できる形に変換する
X_sb = test.drop(['date_time'], axis=1).values

# 表示して確認
X_sb
# Out:
# array([[8.0000e+00, 4.1300e+01, 4.3750e-01, ..., 7.9710e+02, 8.8000e+02,
#         1.2731e+03],
#        [5.1000e+00, 5.1700e+01, 4.5640e-01, ..., 6.8790e+02, 9.7280e+02,
#         1.7140e+03],
#        [5.8000e+00, 5.1500e+01, 4.6890e-01, ..., 6.9370e+02, 9.4190e+02,
#         1.3008e+03],
#        ...,
#        [2.6600e+01, 1.9000e+01, 6.4060e-01, ..., 5.7280e+02, 1.2534e+03,
#         1.0811e+03],
#        [2.9100e+01, 1.2700e+01, 5.1390e-01, ..., 7.0200e+02, 1.0098e+03,
#         8.0850e+02],
#        [2.7900e+01, 1.3500e+01, 5.0280e-01, ..., 6.0820e+02, 1.0613e+03,
#         8.1600e+02]])

# %%
# 各目的変数を回帰
predict_1 = pd.DataFrame(model_1.predict(X_sb.reshape(-1, 8, 1))[:,0])
predict_2 = pd.DataFrame(model_2.predict(X_sb.reshape(-1, 8, 1))[:,0])
predict_3 = pd.DataFrame(model_3.predict(X_sb.reshape(-1, 8, 1))[:,0])

# データの形を確認
predict_1.shape, predict_2.shape, predict_3.shape
# Out:
# ((2247, 1), (2247, 1), (2247, 1))

# %%
# 結果を提出形式に変形
df_predictions = pd.concat([predict_1, predict_2, predict_3],axis=1)
df_predictions.columns = ['target_carbon_monoxide', 'target_benzene', 'target_nitrogen_oxides']
submit_data = pd.concat([test.date_time, df_predictions],axis=1)
submit_data = submit_data.set_index('date_time')
submit_data.head()
# Out:
#                      target_carbon_monoxide  target_benzene  \
# date_time
# 2011-01-01 00:00:00                1.944062        8.376523
# 2011-01-01 01:00:00                1.845290        7.468824
# 2011-01-01 02:00:00                1.879504        7.710185
# 2011-01-01 03:00:00                1.839363        7.433131
# 2011-01-01 04:00:00                1.804640        7.249702
#
#                      target_nitrogen_oxides
# date_time
# 2011-01-01 00:00:00              201.124283
# 2011-01-01 01:00:00              199.827911
# 2011-01-01 02:00:00              200.314606
# 2011-01-01 03:00:00              199.741089
# 2011-01-01 04:00:00              199.213348

# %%
# CSVファイルとして出力
submit_data.to_csv("submission_RNN_GRU.csv")
